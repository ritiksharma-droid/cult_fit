# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

print('Libraries imported successfully.')
# Out:
# Libraries imported successfully.

# %%
df1 = pd.read_csv(r"C:\Users\hp\Downloads\MENTOR SHIP\Fitness_Classes_Data\Fitness Classes Data\Classes April-May 2018.csv")

# %%
df1.head(10)
# Out:
#   ActivitySiteID      ActivityDescription  \
# 0            HXP  20-20-20  2.45pm-3.45pm
# 1            HXP  20-20-20  2.45pm-3.45pm
# 2            HXP  20-20-20  2.45pm-3.45pm
# 3            HXP  20-20-20  2.45pm-3.45pm
# 4            HXP  20-20-20  2.45pm-3.45pm
# 5            HXP  20-20-20  2.45pm-3.45pm
# 6            HXP  20-20-20  2.45pm-3.45pm
# 7            HXP  20-20-20  2.45pm-3.45pm
# 8            TSC     20-20-20 7.00-8.00pm
# 9            TSC     20-20-20 7.00-8.00pm
#
#   BookingEndDateTime (Month / Day / Year) BookingStartTime  MaxBookees  \
# 0                               08-Apr-18         14:45:00          25
# 1                               15-Apr-18         14:45:00          25
# 2                               22-Apr-18         14:45:00          25
# 3                               29-Apr-18         14:45:00          25
# 4                               06-May-18         14:45:00          25
# ...

# %%
df2 = pd.read_csv(r"C:\Users\hp\Downloads\MENTOR SHIP\Fitness_Classes_Data\Fitness Classes Data\Classes June 2018.csv")

# %%
df2.head(10)
# Out:
#   ActivitySiteID      ActivityDescription  \
# 0            BRP   20:20:20  9.30-10.30am
# 1            BRP   20:20:20  9.30-10.30am
# 2            BRP   20:20:20  9.30-10.30am
# 3            BRP   20:20:20  9.30-10.30am
# 4            BRP   20:20:20  9.30-10.30am
# 5            BRP       20:20:20  10-11 Am
# 6            BRP       20:20:20  10-11 Am
# 7            BRP       20:20:20  10-11 Am
# 8            BRP       20:20:20  10-11 Am
# 9            BRP  20:20:20  10.00-11.00am
#
#   BookingEndDateTime (Month / Day / Year) BookingStartTime  MaxBookees  \
# 0                               01-Jun-18          9:30:00          35
# 1                               08-Jun-18          9:30:00          35
# 2                               15-Jun-18          9:30:00          35
# 3                               22-Jun-18          9:30:00          35
# 4                               29-Jun-18          9:30:00          35
# ...

# %%
Cult = pd.concat([df1, df2],axis=0)

# %%
Cult.head(10)
# Out:
#   ActivitySiteID      ActivityDescription  \
# 0            HXP  20-20-20  2.45pm-3.45pm
# 1            HXP  20-20-20  2.45pm-3.45pm
# 2            HXP  20-20-20  2.45pm-3.45pm
# 3            HXP  20-20-20  2.45pm-3.45pm
# 4            HXP  20-20-20  2.45pm-3.45pm
# 5            HXP  20-20-20  2.45pm-3.45pm
# 6            HXP  20-20-20  2.45pm-3.45pm
# 7            HXP  20-20-20  2.45pm-3.45pm
# 8            TSC     20-20-20 7.00-8.00pm
# 9            TSC     20-20-20 7.00-8.00pm
#
#   BookingEndDateTime (Month / Day / Year) BookingStartTime  MaxBookees  \
# 0                               08-Apr-18         14:45:00          25
# 1                               15-Apr-18         14:45:00          25
# 2                               22-Apr-18         14:45:00          25
# 3                               29-Apr-18         14:45:00          25
# 4                               06-May-18         14:45:00          25
# ...

# %%
Cult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3289 entries, 0 to 1111
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ActivitySiteID                           3289 non-null   object
#  1   ActivityDescription                      3289 non-null   object
#  2   BookingEndDateTime (Month / Day / Year)  3289 non-null   object
#  3   BookingStartTime                         3289 non-null   object
#  4   MaxBookees                               3289 non-null   int64
#  5   Number Booked                            3289 non-null   int64
#  6   Price (INR)                              3271 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 205.6+ KB

# %%
Cult.dtypes
# Out:
# ActivitySiteID                              object
# ActivityDescription                         object
# BookingEndDateTime (Month / Day / Year)     object
# BookingStartTime                            object
# MaxBookees                                   int64
# Number Booked                                int64
# Price (INR)                                float64
# dtype: object

# %%
Cult.shape
# Out:
# (3289, 7)

# %%
Cult.columns
# Out:
# Index(['ActivitySiteID', 'ActivityDescription',
#        'BookingEndDateTime (Month / Day / Year)', 'BookingStartTime',
#        'MaxBookees', 'Number Booked', 'Price (INR)'],
#       dtype='object')

# %%
Cult.rename(columns={'BookingEndDateTime (Month / Day / Year)':'BookingEndDateTime'},inplace=True)
Cult.rename(columns={'Number Booked':'Number_Booked'},inplace=True)
Cult.rename(columns={'Price (INR)':'Price'},inplace=True)
print('Rename successfully.')
# Out:
# Rename successfully.

# %%
Cult.columns
# Out:
# Index(['ActivitySiteID', 'ActivityDescription', 'BookingEndDateTime',
#        'BookingStartTime', 'MaxBookees', 'Number_Booked', 'Price'],
#       dtype='object')

# %%
Cult.isnull()
# Out:
#       ActivitySiteID  ActivityDescription  BookingEndDateTime  \
# 0              False                False               False
# 1              False                False               False
# 2              False                False               False
# 3              False                False               False
# 4              False                False               False
# ...              ...                  ...                 ...
# 1107           False                False               False
# 1108           False                False               False
# 1109           False                False               False
# 1110           False                False               False
# 1111           False                False               False
#
#       BookingStartTime  MaxBookees  Number_Booked  Price
# 0                False       False          False  False
# 1                False       False          False  False
# ...

# %%
Cult.isnull().sum()
# Out:
# ActivitySiteID          0
# ActivityDescription     0
# BookingEndDateTime      0
# BookingStartTime        0
# MaxBookees              0
# Number_Booked           0
# Price                  18
# dtype: int64

# %%
Cult = Cult.loc[Cult['Price'].notna()]

# %%
Cult.isnull().sum()
# Out:
# ActivitySiteID         0
# ActivityDescription    0
# BookingEndDateTime     0
# BookingStartTime       0
# MaxBookees             0
# Number_Booked          0
# Price                  0
# dtype: int64

# %%
Cult['BookingEndDateTime'] = pd.to_datetime(Cult['BookingEndDateTime'], format='%d-%b-%y')
Cult.head()
# Out:
#   ActivitySiteID      ActivityDescription BookingEndDateTime BookingStartTime  \
# 0            HXP  20-20-20  2.45pm-3.45pm         2018-04-08         14:45:00
# 1            HXP  20-20-20  2.45pm-3.45pm         2018-04-15         14:45:00
# 2            HXP  20-20-20  2.45pm-3.45pm         2018-04-22         14:45:00
# 3            HXP  20-20-20  2.45pm-3.45pm         2018-04-29         14:45:00
# 4            HXP  20-20-20  2.45pm-3.45pm         2018-05-06         14:45:00
#
#    MaxBookees  Number_Booked  Price
# 0          25             12  499.0
# 1          25             15  499.0
# 2          25             14  499.0
# 3          25              9  499.0
# 4          25              7  499.0

# %%
Cult['BookingEndMonth'] = Cult['BookingEndDateTime'].dt.month
Cult['BookingEndDay'] = Cult['BookingEndDateTime'].dt.day

# %%
Cult['BookingTime']=pd.to_datetime(Cult['BookingStartTime'],format="%H:%M:%S")

# %%
Cult['Booking_Start_Hour']=pd.to_datetime(Cult['BookingStartTime'],format="%H:%M:%S").dt.hour
Cult['Booking_Start_Min']=pd.to_datetime(Cult['BookingStartTime'],format="%H:%M:%S").dt.minute

Cult.head()
# Out:
#   ActivitySiteID      ActivityDescription BookingEndDateTime BookingStartTime  \
# 0            HXP  20-20-20  2.45pm-3.45pm         2018-04-08         14:45:00
# 1            HXP  20-20-20  2.45pm-3.45pm         2018-04-15         14:45:00
# 2            HXP  20-20-20  2.45pm-3.45pm         2018-04-22         14:45:00
# 3            HXP  20-20-20  2.45pm-3.45pm         2018-04-29         14:45:00
# 4            HXP  20-20-20  2.45pm-3.45pm         2018-05-06         14:45:00
#
#    MaxBookees  Number_Booked  Price  BookingEndMonth  BookingEndDay  \
# 0          25             12  499.0                4              8
# 1          25             15  499.0                4             15
# 2          25             14  499.0                4             22
# 3          25              9  499.0                4             29
# 4          25              7  499.0                5              6
#
#           BookingTime  Booking_Start_Hour  Booking_Start_Min
# ...

# %%
Cult.drop('BookingTime',axis=1,inplace=True)
Cult.head()
# Out:
#   ActivitySiteID      ActivityDescription BookingEndDateTime BookingStartTime  \
# 0            HXP  20-20-20  2.45pm-3.45pm         2018-04-08         14:45:00
# 1            HXP  20-20-20  2.45pm-3.45pm         2018-04-15         14:45:00
# 2            HXP  20-20-20  2.45pm-3.45pm         2018-04-22         14:45:00
# 3            HXP  20-20-20  2.45pm-3.45pm         2018-04-29         14:45:00
# 4            HXP  20-20-20  2.45pm-3.45pm         2018-05-06         14:45:00
#
#    MaxBookees  Number_Booked  Price  BookingEndMonth  BookingEndDay  \
# 0          25             12  499.0                4              8
# 1          25             15  499.0                4             15
# 2          25             14  499.0                4             22
# 3          25              9  499.0                4             29
# 4          25              7  499.0                5              6
#
#    Booking_Start_Hour  Booking_Start_Min
# 0                  14                 45
# ...

# %%
print(Cult.duplicated().sum())
# Out:
# 0

# %%
Cult['Activity'] = Cult['ActivityDescription'].str.rsplit(" ",n=1).str[0]
Cult['Activity_Time'] =Cult['ActivityDescription'].str.rsplit(" ",n=1).str[-1]
Cult.head()
# Out:
#   ActivitySiteID      ActivityDescription BookingEndDateTime BookingStartTime  \
# 0            HXP  20-20-20  2.45pm-3.45pm         2018-04-08         14:45:00
# 1            HXP  20-20-20  2.45pm-3.45pm         2018-04-15         14:45:00
# 2            HXP  20-20-20  2.45pm-3.45pm         2018-04-22         14:45:00
# 3            HXP  20-20-20  2.45pm-3.45pm         2018-04-29         14:45:00
# 4            HXP  20-20-20  2.45pm-3.45pm         2018-05-06         14:45:00
#
#    MaxBookees  Number_Booked  Price  BookingEndMonth  BookingEndDay  \
# 0          25             12  499.0                4              8
# 1          25             15  499.0                4             15
# 2          25             14  499.0                4             22
# 3          25              9  499.0                4             29
# 4          25              7  499.0                5              6
#
#    Booking_Start_Hour  Booking_Start_Min   Activity  Activity_Time
# ...

# %%
Cult.isnull().sum()
# Out:
# ActivitySiteID         0
# ActivityDescription    0
# BookingEndDateTime     0
# BookingStartTime       0
# MaxBookees             0
# Number_Booked          0
# Price                  0
# BookingEndMonth        0
# BookingEndDay          0
# Booking_Start_Hour     0
# Booking_Start_Min      0
# Activity               0
# Activity_Time          0
# dtype: int64

# %%
from datetime import datetime, timedelta
print('Libraries imported successfully.')
# Out:
# Libraries imported successfully.

# %%
def create_duration(time_str):
    start_time = datetime.strptime(time_str, '%H:%M:%S')
    end_time = start_time + timedelta(hours=1)
    return f"{start_time.strftime('%I:%M%p')} - {end_time.strftime('%I:%M%p')}"

# %%
Cult['Activity_Time'] = np.where(Cult.Activity_Time, Cult['BookingStartTime'].apply(create_duration),Cult.Activity_Time)

# %%
Cult.drop(columns=['ActivityDescription'],axis=1,inplace=True)
Cult.head()
# Out:
#   ActivitySiteID BookingEndDateTime BookingStartTime  MaxBookees  \
# 0            HXP         2018-04-08         14:45:00          25
# 1            HXP         2018-04-15         14:45:00          25
# 2            HXP         2018-04-22         14:45:00          25
# 3            HXP         2018-04-29         14:45:00          25
# 4            HXP         2018-05-06         14:45:00          25
#
#    Number_Booked  Price  BookingEndMonth  BookingEndDay  Booking_Start_Hour  \
# 0             12  499.0                4              8                  14
# 1             15  499.0                4             15                  14
# 2             14  499.0                4             22                  14
# 3              9  499.0                4             29                  14
# 4              7  499.0                5              6                  14
#
#    Booking_Start_Min   Activity      Activity_Time
# 0                 45  20-20-20   02:45PM - 03:45PM
# ...

# %%
# Function to calculate duration
def calculate_duration(time_range):
    time_range = time_range.replace(" ","")
    time_range = time_range.replace(".Am",'').replace('am',"").replace('AM',"").replace('am',"").replace('Am',"").replace('pm',"").replace('PM',"")
    time_range = time_range.replace('noon', '').replace("Noon","").replace(".",':')
    start_time_str, end_time_str = time_range.split('-')
    
    # Ensure times are in HH:MM format
    if ':' not in start_time_str:
        start_time_str += ':00'
    if ':' not in end_time_str:
        end_time_str += ':00'
    
    print(start_time_str, end_time_str)
    
    # Convert times to datetime objects
    start_time = datetime.strptime(start_time_str, '%H:%M')
    end_time = datetime.strptime(end_time_str, '%H:%M')
    
    if start_time.hour > end_time.hour:
        end_time = end_time.replace(hour=(end_time.hour + 12) % 24)
    
    # Calculate the duration in minutes
    duration = end_time - start_time
    duration_in_minutes = duration.total_seconds() / 60
    
    return duration_in_minutes

# %%
Cult['Activity_Duration'] = Cult['Activity_Time'].apply(calculate_duration)
# Out:
# 02:45 03:45
# 02:45 03:45
# 02:45 03:45
# 02:45 03:45
# 02:45 03:45
# 02:45 03:45
# 02:45 03:45
# 02:45 03:45
# 07:00 08:00
# 07:00 08:00
# 07:00 08:00
# 07:00 08:00
# 07:00 08:00
# 07:00 08:00
# 07:00 08:00
# 07:00 08:00
# 07:00 08:00
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 10:00 11:00
# 10:00 11:00
# 10:00 11:00
# 10:00 11:00
# 10:00 11:00
# 10:00 11:00
# 10:00 11:00
# 10:00 11:00
# 10:00 11:00
# 10:00 11:00
# 10:00 11:00
# 10:00 11:00
# 10:00 11:00
# 10:00 11:00
# 10:00 11:00
# 10:00 11:00
# 10:00 11:00
# 11:00 12:00
# 11:00 12:00
# 11:00 12:00
# 11:00 12:00
# 11:00 12:00
# 11:00 12:00
# 11:00 12:00
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# 09:30 10:30
# ...

# %%
Cult['Activity'] = Cult['Activity'].str.replace(' ', '', regex=False)

# %%
Cult['Activity'] = Cult['Activity'].str.rsplit(" ",n=1).str[0]

# %%
Cult['Activity'] = np.where(Cult['Activity'] == '20:20:20', 
                                   Cult['Activity'].str.replace(':', '-', regex=False), 
                                   Cult['Activity'])

# %%
Cult['Activity'] = np.where(Cult['Activity'] == 'Aquababies/tots', 
                                   Cult['Activity'].str.replace('Aquababies/tots', 'Aquatots&babies', regex=False), 
                                   Cult['Activity'])

# %%
Cult['Activity'] = np.where(Cult['Activity'] == 'Aquatots/baby', 
                                   Cult['Activity'].str.replace('Aquatots/baby', 'Aquatots&babies', regex=False), 
                                   Cult['Activity'])

# %%
Cult['Activity'] = np.where(Cult['Activity'] == 'Aquafit', 
                                   Cult['Activity'].str.replace('Aquafit', 'AquaFit', regex=False), 
                                   Cult['Activity'])

# %%
Cult['Activity'] = np.where(Cult['Activity'] == 'BLT', 
                                   Cult['Activity'].str.replace('BLT', 'BetterLivingTeam', regex=False), 
                                   Cult['Activity'])

# %%
Cult['Activity'] = np.where(Cult['Activity'] == 'Body', 
                                   Cult['Activity'].str.replace('Body', 'BodyAttack', regex=False), 
                                   Cult['Activity'])

# %%
Cult['Activity'] = np.where(Cult['Activity'] == 'BodyBalan', 
                                   Cult['Activity'].str.replace('BodyBalan', 'BodyBalance', regex=False), 
                                   Cult['Activity'])

# %%
Cult['Activity'] = np.where(Cult['Activity'] == 'Better', 
                                   Cult['Activity'].str.replace('Better', 'BetterLivingTeam', regex=False), 
                                   Cult['Activity'])
Cult['Activity'] = np.where(Cult['Activity'] == 'Conditioning', 
                                   Cult['Activity'].str.replace('Conditioning', 'BodyConditioning', regex=False), 
                                   Cult['Activity'])

# %%
Cult['Activity'] = np.where(Cult['Activity'] == 'BodyConditioningd', 
                                   Cult['Activity'].str.replace('BodyConditioningd', 'BodyConditioning', regex=False), 
                                   Cult['Activity'])

# %%
activity_map = {
    'BodyCondition10': 'BodyConditioning',
    'BodyCond3.50pm-': 'BodyConditioning',
    'Bodycondition': 'BodyConditioning',
    'Circuits7-7.45': 'Circuits'
}

Cult['Activity'] = Cult['Activity'].replace(activity_map)

# %%
activity_map = {
    'Circuits8.00-9.00pm': 'Circuits',
    'Fusion5pm': 'Fusion',
    'GentleKeepFit2': 'GentleKeepFit',
    'Gentlekeepfit': 'GentleKeepFit',
    'H.I.T.T6pm-': 'H.I.T.T',
    'H.I.I.T.': 'H.I.T.T',
    'HattonAbcBox': 'HattonABC',
    'HiitCircuit9.30-': 'HiitCircuit'
}

Cult['Activity'] = Cult['Activity'].replace(activity_map)

# %%
activity_map = {
    'JuniorGym11-12': 'JuniorGym',
    'JuniorGym4-5pm': 'JuniorGym',
    'JuniorGym10-11am': 'JuniorGym'
}

Cult['Activity'] = Cult['Activity'].replace(activity_map)

# %%
activity_map = {
    'LegBumTum': 'LegsBumsTums',
    'LegsBumsTum': 'LegsBumsTums',
    'LineDance': 'LineDancing',
    'LineDancing2pm': 'LineDancing'
}

Cult['Activity'] = Cult['Activity'].replace(activity_map)

# %%
activity_map = {
    'Pilates11.00-12.00': 'Pilates',
    'Pilates14:45-': 'Pilates'
}

Cult['Activity'] = Cult['Activity'].replace(activity_map)

# %%
activity_map = {
    'PureStretch11.00': 'PureStretch',
    'RockRollDancing3-': 'RockRollDancing'
}

Cult['Activity'] = Cult['Activity'].replace(activity_map)

# %%
activity_map = {
    'JnrGymInd': 'JunInduction',
    'Sh`Bam': 'Sha`Bam',
    'Step': 'StepAerobics',
    'Step': 'StepZumba',
    'Strength&stretch1230-1330': 'Strength&stretch',
    'Stretch': 'Strength&stretch',
    'Stretch6pm': 'Strength&stretch'
}

Cult['Activity'] = Cult['Activity'].replace(activity_map)

# %%
activity_map = {
    'Stroke': 'Strokeskills',
    'Strokeskills6': 'Strokeskills',
    'Strokeskills6pm-': 'Strokeskills',
    'Strokeskills7pm': 'Strokeskills',
    'StudioCyc1.10-': 'StudioCyc',
    'StudioCyc10.00': 'StudioCyc',
    'StudioCyc11.30-': 'StudioCyc',
    'StudioCycling7.05': 'StudioCyc'

}

Cult['Activity'] =Cult['Activity'].replace(activity_map)

# %%
activity_map = {
    'Swim': 'Swimfit',
    'Swimfit7am-': 'Swimfit',
    'Swimfit8pm-': 'Swimfit',
    'Swimfit6.30': 'Swimfit',
    'Swimfit6.30am': 'Swimfit',
    'Swimfit7pm-': 'Swimfit',
    'Tai-Chi12': 'TaiChi',
    'Zumba6.00-': 'Zumba',
    'BodyAttack9-10': 'BodyAttack',
    'Strokeskills7pm': 'Strokeskills',
    'StudioCyc9.05': 'StudioCyc',
    '5.30-6.30pmBody': 'BodyConditioning',
    'Combat': 'BodyCombat',
    'Zumba-': 'Zumba'
}

Cult['Activity'] = Cult['Activity'].replace(activity_map)

# %%
Cult.sort_values('BookingEndDateTime',ignore_index=True,inplace=True)
